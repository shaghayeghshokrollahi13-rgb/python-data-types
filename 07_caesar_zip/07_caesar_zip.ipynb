# %%
#1
mylist=[("sara",1),("ali",2),("neda",3)]
print(list(zip(*mylist)))
# Out:
# [('sara', 'ali', 'neda'), (1, 2, 3)]

# %%
#2
coordinate=["x","y","z"]
value=[3,4,5]
result=zip(coordinate,value)
result_list= list(result)
print(result_list)
c,v=zip(*result_list)
print("c=",c)
print("v=",v)
# Out:
# [('x', 3), ('y', 4), ('z', 5)]
# c= ('x', 'y', 'z')
# v= (3, 4, 5)

# %%
#3
names=["ali","sara","reza"]
ages=[25,30,22]
for n, a in zip(names,ages):
    print(n,a)
# Out:
# ali 25
# sara 30
# reza 22

# %%
#4
message="Hello,start the attack"
code=""
i=len(message)-1
while i>=0:
    code=code+message[i]
    i=i-1
print(code)
# Out:
# kcatta eht trats,olleH

# %%
#5
text="hello ,stars the attack"
result=""
s=4
for i in range(len(text)):
    char=text[i]
    if (char.isupper()):
        result=result+chr((ord(char)+s-65)%26+65)
    else:
        result=result+chr((ord(char)+s-97)%26+97)
print(result)
# Out:
# lippsrdwxevwrxlirexxego

# %%
#6
text="lippsrdwxevwrxlirexxego"

result=""
s=4
for i in range(len(text)):
    char=text[i]
    if(char.isupper()):
        result=result+chr((ord(char)-s-65)%26+65)
    else:
        result=result+chr((ord(char)-s-97)%26+97)
print(result)
# Out:
# hellonzstarsnthenattack
