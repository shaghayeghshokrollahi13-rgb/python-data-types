# %%
#1
dict1={"first_name":"shaghayegh","last_name":"shokrollahi","age":25}
print(dict["first_name"])
print(dict["age"])
# Out:
# shaghayegh
# 25

# %%
#2
dict1={"first_name":"shaghayegh","last_name":"shokrollahi","age":25}
dict.clear()
print(dict["first_name"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 4
#       2 dict1={"first_name":"shaghayegh","last_name":"shokrollahi","age":25}
#       3 dict.clear()
# ----> 4 print(dict["first_name"])
#
# KeyError: 'first_name'

# %%
#3
dict1={"first_name":"shaghayegh","last_name":"shokrollahi","age":25}
del dict1
print(dict1["age"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       2 dict1={"first_name":"shaghayegh","last_name":"shokrollahi","age":25}
#       3 del dict1
# ----> 4 print(dict1["age"])
#
# NameError: name 'dict1' is not defined

# %%
#4
my_dict = {'C1':[1,2,3],'C2':[5,6,7],'C3':[9,10,11]}
print(my_dict["C1"])
# Out:
# [1, 2, 3]

# %%
#5
mydict={"first_name":"shaghayegh","last_name":"shokrollahi","age":25}
mydict["ID"]=12345
print(mydict)
# Out:
# {'first_name': 'shaghayegh', 'last_name': 'shokrollahi', 'age': 25, 'ID': 12345}

# %%
#6
x={"name":["ali","sasan","omid"],"age":[23,32,35]}
x.pop("name")
print(x)
# Out:
# {'age': [23, 32, 35]}

# %%
#7
for i in range(4):
    s=i**3
    print(i," ",s)
# Out:
# 0   0
# 1   1
# 2   8
# 3   27

# %%
#8
s={i:i**3 for i in range(4)}
print(s)
# Out:
# {0: 0, 1: 1, 2: 8, 3: 27}

# %%
#9
s={i:i*i for i in range(15,35) if i%2==0}
print(s)
# Out:
# {16: 256, 18: 324, 20: 400, 22: 484, 24: 576, 26: 676, 28: 784, 30: 900, 32: 1024, 34: 1156}

# %%
#10
N={1:2,3:6,4:8,5:10}
print(len(N))
# Out:
# 4

# %%
#11
s={1:2,2:22,3:33,4:44}
print(sorted(s))
# Out:
# [1, 2, 3, 4]

# %%
#12
r_list=[["ali",23],["reza",36]]
r_dict=dict(r_list)
print(r_dict)
# Out:
# {'ali': 23, 'reza': 36}

# %%
#13
keys = ['red', 'green', 'blue']
values = ['#FF0000','#008000', '#0000FF'] 
color_dict=dict(zip(keys,values))
print(color_dict)
# Out:
# {'red': '#FF0000', 'green': '#008000', 'blue': '#0000FF'}

# %%
#14
mydic1={1:"Ali",2:"reza"}
mydic2={3:"zahra",4:"neda"}
mydic1.update(mydic2)
print(mydic1)
# Out:
# {1: 'Ali', 2: 'reza', 3: 'zahra', 4: 'neda'}

# %%
#15
mydict={1:"Ali",2:"Reza"}
print(mydict.keys())
print(mydict.values())
print(mydict.items())
# Out:
# dict_keys([1, 2])
# dict_values(['Ali', 'Reza'])
# dict_items([(1, 'Ali'), (2, 'Reza')])

# %%
#16
new_dic={"data1":12,"data2":-13,"data3":24}
result=1
for i in new_dic:
    result=result*new_dic[i]
print(result)
# Out:
# -3744

# %%
#17
s_set={"sara","rosha",3}
for x in s_set:
    print(x)
# Out:
# sara
# 3
# rosha

# %%
#18
s_set={"ali","sasan",225}
s_set.add("sara")
print(s_set)
# Out:
# {'sasan', 225, 'ali', 'sara'}

# %%
s_set.add(880)
print(s_set)
# Out:
# {225, 'sasan', 880, 'ali', 'sara'}

# %%
#19
N_set={"sasan","rosha",220,880}
N_set.update([777,"neda"])
print(N_set)
# Out:
# {'neda', 777, 'sasan', 880, 'rosha', 220}

# %%
#20
s_set={225, 'sasan', 880, 'ali', 'sara'}
s_set.remove(880)
print(s_set)
# Out:
# {'sasan', 225, 'ali', 'sara'}

# %%
#20
s_set={'sasan', 225, 'ali', 'sara'}
s_set.discard("sasan")
print(s_set)
# Out:
# {225, 'ali', 'sara'}

# %%
#21
set1={1,2,3}
set2={"sasan","naze"}
set1.update(set2)
print(set1)
# Out:
# {'sasan', 1, 2, 3, 'naze'}

# %%
#22
set1={1,2,5}
set2={"red","black"}
set3=set1.union(set2)
print(set3)
# Out:
# {1, 2, 'red', 5, 'black'}

# %%
#23
s_set=set(("ali","reza"))
print(s_set)
# Out:
# {'ali', 'reza'}

# %%
#24
set1={1,2,3,4,5}
set2={1,2,3,4,5,6,7,8,9}
set3=set1.intersection(set2)
print(set3)
# Out:
# {1, 2, 3, 4, 5}

# %%
#25
set1={1,3,5,7,9,13}
set2={1,2,3,4,5,6,7,8}
set3=set1&set2
print(set3)
# Out:
# {1, 3, 5, 7}

# %%
#26
set1={1,2,3,4,5,6}
set2={1,2,3,7,8,9}
set3=set2.difference(set1)
print(set3)
# Out:
# {8, 9, 7}

# %%
#27
new={1,2,3,4,5,6,0}
new2={1,2,3,4,8,9,7}
set3=set1.symmetric_difference(set2)
print(set3)
# Out:
# {4, 5, 6, 7, 8, 9}

# %%
#28
my_list=[]
n=int(input("enter number of elements:"))
for i in range(0,n):
    ele=int(input("adding the element:"))
    my_list.append(ele)
print(my_list)
# Out:
# enter number of elements: 5
# adding the element: 12
# adding the element: 25
# adding the element: 26
# adding the element: 23
# adding the element: 28
# [12, 25, 26, 23, 28]

# %%
#29
my_list=[]
n=int(input("enter number of elements:"))
for i in range(0,n):

    ele=[input("name:"),int(input(" age:"))]
    my_list.append(ele)
print(my_list)
# Out:
# enter number of elements: 2
# name: shaghayegh
#  age: 23
# name: sara
#  age: 18
# [['shaghayegh', 23], ['sara', 18]]

# %%
#30
mylist=[]
n=int(input("enter number of elements:"))
for i in range(0,n):
    ele=[input("name:"),int(input("age"))]
    mylist.append(ele)
    mydic=dict(mylist)
print(mydic)
# Out:
# enter number of elements: 3
# name: shaghayegh
# age 23
# name: rosha
# age 2
# name: sara
# age 29
# {'shaghayegh': 23, 'rosha': 2, 'sara': 29}
